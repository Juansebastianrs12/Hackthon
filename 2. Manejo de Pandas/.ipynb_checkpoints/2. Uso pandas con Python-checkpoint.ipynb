# %% [markdown]
# # Módulo 4:  _Modelos de Analítica Aplicados a los Negocios_

# %% [markdown]
# <div align="center"><h2>Carga de datasets y visualización de información</h2></div>

# %% [markdown]
# <img src="img/logos.png" >

# %% [markdown]
# # **Manejo de Pandas**
#
# <img src="img/logo_pandas.png" width="400px">
# La visualización de datos en Data Science no siempre es posible hacer en gráficas, en muchas ocasiones debedo a la gran cantidad de datos, la única forma es mostrar los datos crudos.
#
#
# <a href="https://pandas.pydata.org/" target="_blank">Página oficial de Pandas</a>

# %% [markdown]
# ## **Carga de librería**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Cargar archivos**

# %%
pwd
# Out:
# '/Users/juancamilosanchez/Downloads/Manejo de pd-np-plt/2. Manejo de Pandas/.ipynb_checkpoints'

# %%
df_oro = pd.read_csv('../DataSets/Datos_históricos_Futuros_oro.csv') 
df_oro
# Out:
#           Fecha    Último  Apertura    Máximo    Mínimo     Vol.  % var.
# 0    11.10.2021  1.753,95  1.754,10  1.761,10  1.750,05        -  -0,01%
# 1    10.10.2021  1.754,20  1.757,25  1.758,65  1.751,20        -  -0,18%
# 2    08.10.2021  1.757,40  1.757,00  1.782,40  1.753,60  240,37K  -0,10%
# 3    07.10.2021  1.759,20  1.763,80  1.767,70  1.752,00  146,41K  -0,15%
# 4    06.10.2021  1.761,80  1.760,50  1.765,90  1.745,40  159,22K   0,05%
# ..          ...       ...       ...       ...       ...      ...     ...
# 202  07.01.2021  1.924,00  1.933,80  1.938,00  1.920,70    3,30K   0,24%
# 203  06.01.2021  1.919,40  1.965,60  1.971,50  1.914,40    3,81K  -2,33%
# 204  05.01.2021  1.965,20  1.955,00  1.965,90  1.953,70    2,22K   0,39%
# 205  04.01.2021  1.957,60  1.927,20  1.959,20  1.926,90    1,25K   2,94%
# 206  01.01.2021  1.901,60  1.901,60  1.901,60  1.901,60        -  -0,22%
#
# [207 rows x 7 columns]

# %%
primeros_df_oro=df_oro.head(10)
primeros_df_oro
# Out:
#         Fecha    Último  Apertura    Máximo    Mínimo     Vol.  % var.
# 0  11.10.2021  1.753,95  1.754,10  1.761,10  1.750,05        -  -0,01%
# 1  10.10.2021  1.754,20  1.757,25  1.758,65  1.751,20        -  -0,18%
# 2  08.10.2021  1.757,40  1.757,00  1.782,40  1.753,60  240,37K  -0,10%
# 3  07.10.2021  1.759,20  1.763,80  1.767,70  1.752,00  146,41K  -0,15%
# 4  06.10.2021  1.761,80  1.760,50  1.765,90  1.745,40  159,22K   0,05%
# 5  05.10.2021  1.760,90  1.770,80  1.771,10  1.748,60  151,42K  -0,38%
# 6  04.10.2021  1.767,60  1.762,60  1.771,50  1.747,70  166,18K   0,52%
# 7  01.10.2021  1.758,40  1.757,20  1.765,20  1.749,90  151,20K   0,08%
# 8  30.09.2021  1.757,00  1.726,00  1.765,00  1.721,80  246,37K   1,98%
# 9  29.09.2021  1.722,90  1.734,00  1.746,00  1.721,10  177,39K  -0,84%

# %%
df_oro = pd.read_excel('../DataSets/Datos_históricos_Futuros_oro.xlsx') 
df_oro
# Out:
#           Fecha   Último  Apertura   Máximo   Mínimo     Vol.  % var.
# 0    11.10.2021  1753.95   1754.10  1761.10  1750.05        - -0.0001
# 1    10.10.2021  1754.20   1757.25  1758.65  1751.20        - -0.0018
# 2    08.10.2021  1757.40   1757.00  1782.40  1753.60  240,37K -0.0010
# 3    07.10.2021  1759.20   1763.80  1767.70  1752.00  146,41K -0.0015
# 4    06.10.2021  1761.80   1760.50  1765.90  1745.40  159,22K  0.0005
# ..          ...      ...       ...      ...      ...      ...     ...
# 202  07.01.2021  1924.00   1933.80  1938.00  1920.70    3,30K  0.0024
# 203  06.01.2021  1919.40   1965.60  1971.50  1914.40    3,81K -0.0233
# 204  05.01.2021  1965.20   1955.00  1965.90  1953.70    2,22K  0.0039
# 205  04.01.2021  1957.60   1927.20  1959.20  1926.90    1,25K  0.0294
# 206  01.01.2021  1901.60   1901.60  1901.60  1901.60        - -0.0022
#
# [207 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

y_ultimo = df_oro['Último'] # Extraer columna de un DF
y_max = df_oro['Máximo']
y_min = df_oro['Mínimo']

plt.figure(figsize=(15,5))
plt.plot(y_ultimo ,'-', label='Valor')
plt.plot(y_max , '--',label='Max')
plt.plot(y_min , '--', label='Min')
plt.title('histórico del oro')
plt.xlabel('Días de 2021')
plt.ylabel('Pesos')
plt.legend()
plt.grid()
plt.show()

# %%
y_ultimo = list(df_oro['Último']) # Extraer columna de un DF
y_max = list(df_oro['Máximo'])
y_min = list(df_oro['Mínimo'])
y_ultimo.reverse()
y_max.reverse()
y_min.reverse()
plt.figure(figsize=(15,5))
plt.plot(y_ultimo ,'-*', label='Valor')
plt.plot(y_max , '--',label='Max')
plt.plot(y_min , '--', label='Min')
plt.title('histórico del oro')
plt.xlabel('Días de 2021')
plt.ylabel('Pesos')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## **Uso de LOC**
# Se usa para extraer segmentos del DF, utilizando los nombres de las columnas o filas.

# %%
# Traer una sola columan con todas las fila
df_oro.loc[:,'Último']
# Out:
# 0      1753.95
# 1      1754.20
# 2      1757.40
# 3      1759.20
# 4      1761.80
#         ...
# 202    1924.00
# 203    1919.40
# 204    1965.20
# 205    1957.60
# 206    1901.60
# Name: Último, Length: 207, dtype: float64

# %%
# Traer una fila y todas las columna
pd.DataFrame(df_oro.loc[3,:]).transpose()
# Out:
#         Fecha  Último Apertura  Máximo  Mínimo     Vol.  % var.
# 3  07.10.2021  1759.2   1763.8  1767.7  1752.0  146,41K -0.0015

# %%
# Traer varias filas y columnas consecutivas
df_oro.loc[:20 , 'Apertura':'Mínimo']
# Out:
#     Apertura   Máximo   Mínimo
# 0    1754.10  1761.10  1750.05
# 1    1757.25  1758.65  1751.20
# 2    1757.00  1782.40  1753.60
# 3    1763.80  1767.70  1752.00
# 4    1760.50  1765.90  1745.40
# 5    1770.80  1771.10  1748.60
# 6    1762.60  1771.50  1747.70
# 7    1757.20  1765.20  1749.90
# 8    1726.00  1765.00  1721.80
# 9    1734.00  1746.00  1721.10
# 10   1750.00  1754.30  1727.80
# 11   1751.80  1760.90  1744.70
# 12   1743.70  1758.00  1740.20
# 13   1769.20  1777.10  1737.50
# 14   1775.00  1788.40  1764.60
# 15   1765.50  1782.80  1758.30
# 16   1754.20  1768.40  1742.30
# 17   1754.60  1767.80  1747.10
# 18   1795.50  1797.30  1745.50
# 19   1806.60  1808.50  1791.70
# 20   1794.80  1810.60  1780.60

# %%
# Traer varias columnas específicas, seleccionadas en cualquier orden

df_select = df_oro.loc[[0,99,5,70,100],['Fecha','% var.','Último']]
df_select
# Out:
#           Fecha  % var.   Último
# 0    11.10.2021 -0.0001  1753.95
# 99   30.05.2021  0.0008  1906.75
# 5    05.10.2021 -0.0038  1760.90
# 70   07.07.2021  0.0044  1802.10
# 100  28.05.2021  0.0036  1905.30

# %%
df_select.loc[:,'Fecha']
# Out:
# 0      11.10.2021
# 99     30.05.2021
# 5      05.10.2021
# 70     07.07.2021
# 100    28.05.2021
# Name: Fecha, dtype: object

# %%
df_oro
# Out:
#           Fecha   Último  Apertura   Máximo   Mínimo     Vol.  % var.
# 0    11.10.2021  1753.95   1754.10  1761.10  1750.05        - -0.0001
# 1    10.10.2021  1754.20   1757.25  1758.65  1751.20        - -0.0018
# 2    08.10.2021  1757.40   1757.00  1782.40  1753.60  240,37K -0.0010
# 3    07.10.2021  1759.20   1763.80  1767.70  1752.00  146,41K -0.0015
# 4    06.10.2021  1761.80   1760.50  1765.90  1745.40  159,22K  0.0005
# ..          ...      ...       ...      ...      ...      ...     ...
# 202  07.01.2021  1924.00   1933.80  1938.00  1920.70    3,30K  0.0024
# 203  06.01.2021  1919.40   1965.60  1971.50  1914.40    3,81K -0.0233
# 204  05.01.2021  1965.20   1955.00  1965.90  1953.70    2,22K  0.0039
# 205  04.01.2021  1957.60   1927.20  1959.20  1926.90    1,25K  0.0294
# 206  01.01.2021  1901.60   1901.60  1901.60  1901.60        - -0.0022
#
# [207 rows x 7 columns]

# %% [markdown]
# ## **Uso del iLOC**
# Se usa para extraer segmentos del DF, utilizando los **números** de las columnas o filas.

# %%
# Todas las filas con una columna
df_oro.iloc[:,6]
# Out:
# 0     -0.0001
# 1     -0.0018
# 2     -0.0010
# 3     -0.0015
# 4      0.0005
#         ...
# 202    0.0024
# 203   -0.0233
# 204    0.0039
# 205    0.0294
# 206   -0.0022
# Name: % var., Length: 207, dtype: float64

# %%
# todas las columnas con una sola fila
pd.DataFrame(df_oro.iloc[100 , :]).transpose()
# Out:
#           Fecha  Último Apertura  Máximo  Mínimo     Vol.  % var.
# 100  28.05.2021  1905.3   1899.8  1908.8  1884.3  198,14K  0.0036

# %%
# traer varias filas y varias columnas en orden.
df_oro.iloc[100:,4:]
# Out:
#      Mínimo     Vol.  % var.
# 100  1884.3  198,14K  0.0036
# 101  1890.8  211,79K -0.0028
# 102  1893.0  178,18K  0.0017
# 103  1875.4  176,60K  0.0073
# 104  1877.9   55,84K  0.0042
# ..      ...      ...     ...
# 202  1920.7    3,30K  0.0024
# 203  1914.4    3,81K -0.0233
# 204  1953.7    2,22K  0.0039
# 205  1926.9    1,25K  0.0294
# 206  1901.6        - -0.0022
#
# [107 rows x 3 columns]

# %%
# traer varias filas y varias columnas en un orden específico
df_oro.iloc[[23, 99, 1, 5, 0],[5,0,2]]
# Out:
#        Vol.       Fecha  Apertura
# 23  154,13K  09.09.2021   1790.90
# 99        -  30.05.2021   1907.60
# 1         -  10.10.2021   1757.25
# 5   151,42K  05.10.2021   1770.80
# 0         -  11.10.2021   1754.10

# %% [markdown]
# ## **Uso de AT**
# Acceder al un valor específico del DF usando los nombre de fila y columna

# %%
df_oro.at[0,'Fecha']
# Out:
# '11.10.2021'

# %% [markdown]
# ## **Uso de iAT**
# Acceder al un valor específico del DF usando los **número** de fila y columna

# %%
df_oro.iat[0,4]
# Out:
# 1750.05

# %% [markdown]
# .

# %%
df_oro
# Out:
#           Fecha   Último  Apertura   Máximo   Mínimo     Vol.  % var.
# 0    11.10.2021  1753.95   1754.10  1761.10  1750.05        - -0.0001
# 1    10.10.2021  1754.20   1757.25  1758.65  1751.20        - -0.0018
# 2    08.10.2021  1757.40   1757.00  1782.40  1753.60  240,37K -0.0010
# 3    07.10.2021  1759.20   1763.80  1767.70  1752.00  146,41K -0.0015
# 4    06.10.2021  1761.80   1760.50  1765.90  1745.40  159,22K  0.0005
# ..          ...      ...       ...      ...      ...      ...     ...
# 202  07.01.2021  1924.00   1933.80  1938.00  1920.70    3,30K  0.0024
# 203  06.01.2021  1919.40   1965.60  1971.50  1914.40    3,81K -0.0233
# 204  05.01.2021  1965.20   1955.00  1965.90  1953.70    2,22K  0.0039
# 205  04.01.2021  1957.60   1927.20  1959.20  1926.90    1,25K  0.0294
# 206  01.01.2021  1901.60   1901.60  1901.60  1901.60        - -0.0022
#
# [207 rows x 7 columns]

# %%
df_oro['Vol.']
# Out:
# 0            -
# 1            -
# 2      240,37K
# 3      146,41K
# 4      159,22K
#         ...
# 202      3,30K
# 203      3,81K
# 204      2,22K
# 205      1,25K
# 206          -
# Name: Vol., Length: 207, dtype: object

# %%
df_oro['Vol.'] = df_oro['Vol.'].replace('-','0')
df_oro
# Out:
#           Fecha   Último  Apertura   Máximo   Mínimo     Vol.  % var.
# 0    11.10.2021  1753.95   1754.10  1761.10  1750.05        0 -0.0001
# 1    10.10.2021  1754.20   1757.25  1758.65  1751.20        0 -0.0018
# 2    08.10.2021  1757.40   1757.00  1782.40  1753.60  240,37K -0.0010
# 3    07.10.2021  1759.20   1763.80  1767.70  1752.00  146,41K -0.0015
# 4    06.10.2021  1761.80   1760.50  1765.90  1745.40  159,22K  0.0005
# ..          ...      ...       ...      ...      ...      ...     ...
# 202  07.01.2021  1924.00   1933.80  1938.00  1920.70    3,30K  0.0024
# 203  06.01.2021  1919.40   1965.60  1971.50  1914.40    3,81K -0.0233
# 204  05.01.2021  1965.20   1955.00  1965.90  1953.70    2,22K  0.0039
# 205  04.01.2021  1957.60   1927.20  1959.20  1926.90    1,25K  0.0294
# 206  01.01.2021  1901.60   1901.60  1901.60  1901.60        0 -0.0022
#
# [207 rows x 7 columns]

# %%
df_oro.at[3,'% var.']
# Out:
# -0.0015

# %%
df_oro.at[3,'% var.'] = -0.0001
df_oro
# Out:
#           Fecha   Último  Apertura   Máximo   Mínimo     Vol.  % var.
# 0    11.10.2021  1753.95   1754.10  1761.10  1750.05        0 -0.0001
# 1    10.10.2021  1754.20   1757.25  1758.65  1751.20        0 -0.0018
# 2    08.10.2021  1757.40   1757.00  1782.40  1753.60  240,37K -0.0010
# 3    07.10.2021  1759.20   1763.80  1767.70  1752.00  146,41K -0.0001
# 4    06.10.2021  1761.80   1760.50  1765.90  1745.40  159,22K  0.0005
# ..          ...      ...       ...      ...      ...      ...     ...
# 202  07.01.2021  1924.00   1933.80  1938.00  1920.70    3,30K  0.0024
# 203  06.01.2021  1919.40   1965.60  1971.50  1914.40    3,81K -0.0233
# 204  05.01.2021  1965.20   1955.00  1965.90  1953.70    2,22K  0.0039
# 205  04.01.2021  1957.60   1927.20  1959.20  1926.90    1,25K  0.0294
# 206  01.01.2021  1901.60   1901.60  1901.60  1901.60        0 -0.0022
#
# [207 rows x 7 columns]

# %% [markdown]
# ## **Forma , tamaño o dimensiones de DF**

# %%
print(df_oro.shape)
print('Filas:',df_oro.shape[0])
print('Columnas:',df_oro.shape[1])
# Out:
# (207, 7)
# Filas: 207
# Columnas: 7

# %% [markdown]
# ## **Construir un DF en pandas desde cero**

# %%
new_col = pd.DataFrame(np.arange(df_oro.shape[0]))
new_col
# Out:
#        0
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 202  202
# 203  203
# 204  204
# 205  205
# 206  206
#
# [207 rows x 1 columns]

# %%
# Construir DF a partir de una lista
lenguajes = ['Python' , 'Java' , 'JavaScript' , 'C' , 'C++' , 'R' , 'C#' , 'Cotlin']

df2 = pd.DataFrame(lenguajes)
df2.columns = ['Lenguajes'] # Poner nombre a columnas
df2
# Out:
#     Lenguajes
# 0      Python
# 1        Java
# 2  JavaScript
# 3           C
# 4         C++
# 5           R
# 6          C#
# 7      Cotlin

# %%
# Construir un DF a partir de un diccionario
data = {
    0 : ['Juan' , 'Sofía' , 'Carlos' , 'Martha'] ,
    1 : [20 , 21 , 19 , 18],
    2 : [4.5 , 3.6 , 3.3 , 4.2]
}

df3 = pd.DataFrame(data)
df3.columns = ['Nombre' , 'Edad' , 'Nota']
df3
# Out:
#    Nombre  Edad  Nota
# 0    Juan    20   4.5
# 1   Sofía    21   3.6
# 2  Carlos    19   3.3
# 3  Martha    18   4.2

# %%
# Construir un DF a partir de un diccionario
data2 = {
    'Nombre2' : ['Juan' , 'Sofía' , 'Carlos' , 'Martha'] ,
    'Edad2' : [20 , 21 , 19 , 18],
    'Nota2' : [4.5 , 3.6 , 3.3 , 4.2]
}

df32 = pd.DataFrame(data2)
df32
# Out:
#   Nombre2  Edad2  Nota2
# 0    Juan     20    4.5
# 1   Sofía     21    3.6
# 2  Carlos     19    3.3
# 3  Martha     18    4.2

# %%
df32.index = ['Alumno1','Alumno2','Alumno3','Alumno4']
df32
# Out:
#         Nombre2  Edad2  Nota2
# Alumno1    Juan     20    4.5
# Alumno2   Sofía     21    3.6
# Alumno3  Carlos     19    3.3
# Alumno4  Martha     18    4.2

# %%
df32.at['Alumno2','Nombre2']
# Out:
# 'Sofía'

# %%
df32.iat[1 , 0]
# Out:
# 'Sofía'

# %% [markdown]
# ## **Los DF se pueden concatenar**

# %%
df4 = pd.DataFrame({
  'A' : ['A0','A1','A2','A3'],
  'B' : ['B0','B1','B2','B3'],
  'C' : ['C0','C1','C2','C3'],
  'D' : ['D0','D1','D2','D3'],
})

df5 = pd.DataFrame({
  'A' : ['A4','A5','A6','A7'],
  'B' : ['B4','B5','B6','B7'],
  'C' : ['C4','C5','C6','C7'],
  'D' : ['D4','D5','D6','D7'],
})

df6 = pd.DataFrame({
  'A' : ['A8','A9','A10','A11'],
  'B' : ['B8','B9','B10','B11'],
  'C' : ['C8','C9','C10','C11'],
  'D' : ['D8','D9','D10','D11'],
})

df7 = pd.concat([df4 , df5, df6] ,axis=0)
df7
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
df8 = pd.DataFrame({
    'E' : ['E1', 'E2', 'E3','E4'],
    'F' : ['F1', 'F2', 'F3','F4'],
    'G' : ['G1', 'G2', 'G3','G4'],
})

df9 = pd.concat([df8 , df4] , axis=1)
df9
# Out:
#     E   F   G   A   B   C   D
# 0  E1  F1  G1  A0  B0  C0  D0
# 1  E2  F2  G2  A1  B1  C1  D1
# 2  E3  F3  G3  A2  B2  C2  D2
# 3  E4  F4  G4  A3  B3  C3  D3

# %% [markdown]
# ## **Se pueden eliminar (Drop) columna del DF**

# %%
df10 = df9.drop(['F', 'C'] , axis=1)
df10
# Out:
#     E   G   A   B   D
# 0  E1  G1  A0  B0  D0
# 1  E2  G2  A1  B1  D1
# 2  E3  G3  A2  B2  D2
# 3  E4  G4  A3  B3  D3

# %%
df9
# Out:
#     E   F   G   A   B   C   D
# 0  E1  F1  G1  A0  B0  C0  D0
# 1  E2  F2  G2  A1  B1  C1  D1
# 2  E3  F3  G3  A2  B2  C2  D2
# 3  E4  F4  G4  A3  B3  C3  D3

# %%
df9.drop(['A'],axis=1,inplace=True)
df9
# Out:
#     E   F   G   B   C   D
# 0  E1  F1  G1  B0  C0  D0
# 1  E2  F2  G2  B1  C1  D1
# 2  E3  F3  G3  B2  C2  D2
# 3  E4  F4  G4  B3  C3  D3

# %%
df9.drop(['F'],axis=1)
# Out:
#     E   G   B   C   D
# 0  E1  G1  B0  C0  D0
# 1  E2  G2  B1  C1  D1
# 2  E3  G3  B2  C2  D2
# 3  E4  G4  B3  C3  D3

# %% [markdown]
# ## **Se pueden eliminar (Drop) filas**

# %%
# Eliminar filas
df9.drop(2 , axis=0 , inplace=True)
df9
# Out:
#     E   F   G   B   C   D
# 0  E1  F1  G1  B0  C0  D0
# 1  E2  F2  G2  B1  C1  D1
# 3  E4  F4  G4  B3  C3  D3

# %% [markdown]
# # **Otro ejercicios con DF**

# %%
dataset = pd.read_excel('../DataSets/dataset.xlsx')
dataset
# Out:
#     Unnamed: 0          Id         Nombre   Apellido  Edad    Dirección  \
# 0            0     7658908           Juan   Martínez    23  Calle 45 67
# 1            1  1234325678          Mario       Soto    43          NaN
# 2            2    43567832          Marta   Cárdenas    56    Cra 23 98
# 3            3    32567854  Diana Marcela     Zapata    76     Av 32 98
# 4            4    29876009  Maria Cecilia    Aguirre    87          NaN
# 5            5  1000987566         Camilo    Aguilar    84    Cll 45 90
# 6            6  1001456765       Jhonatan       Toro    37    Crr 12 87
# 7            7    71234543        Armando   Pulgarín    28     Cir 5 67
# 8            8    70987899    Juan Carlos     Suarez    23  Trans 56 21
# 9            9     8765679         Dayana  Velásquez    21          NaN
# 10          10    15435211        Shirley    Cuartas    34          NaN
# 11          11  1000900877         Isabel       Ossa    36          NaN
# 12          12    98000654   Maria Camila      Ortiz    39  Calle 66 11
# 13          13    56432555         Andrea   Calderón    43    Cra 99 12
# 14          14  1000098077          Laura     Torres    65      Av 5 34
#
#      Teléfono Facebook Twitter
# 0   1234567.0       Si      Si
# 1   1122334.0       Si     NaN
# 2   3456787.0       No     NaN
# 3   2567843.0       No     NaN
# 4   5673212.0       No      Si
# 5         NaN       No     NaN
# 6         NaN       Si     NaN
# 7   3249988.0       Si     NaN
# 8         NaN       Si      Si
# 9   4350011.0       Si     NaN
# 10  3159800.0       Si     NaN
# 11  9876543.0       Si     NaN
# 12  6453211.0      NaN      Si
# 13        NaN       Si     NaN
# 14  3354422.0       No      Si

# %%
dataset.shape
# Out:
# (15, 9)

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Nombre', 'Apellido', 'Edad', 'Dirección',
#        'Teléfono', 'Facebook', 'Twitter'],
#       dtype='object')

# %%
dataset.drop(['Unnamed: 0'],axis=1, inplace=True)
dataset
# Out:
#             Id         Nombre   Apellido  Edad    Dirección   Teléfono  \
# 0      7658908           Juan   Martínez    23  Calle 45 67  1234567.0
# 1   1234325678          Mario       Soto    43          NaN  1122334.0
# 2     43567832          Marta   Cárdenas    56    Cra 23 98  3456787.0
# 3     32567854  Diana Marcela     Zapata    76     Av 32 98  2567843.0
# 4     29876009  Maria Cecilia    Aguirre    87          NaN  5673212.0
# 5   1000987566         Camilo    Aguilar    84    Cll 45 90        NaN
# 6   1001456765       Jhonatan       Toro    37    Crr 12 87        NaN
# 7     71234543        Armando   Pulgarín    28     Cir 5 67  3249988.0
# 8     70987899    Juan Carlos     Suarez    23  Trans 56 21        NaN
# 9      8765679         Dayana  Velásquez    21          NaN  4350011.0
# 10    15435211        Shirley    Cuartas    34          NaN  3159800.0
# 11  1000900877         Isabel       Ossa    36          NaN  9876543.0
# 12    98000654   Maria Camila      Ortiz    39  Calle 66 11  6453211.0
# 13    56432555         Andrea   Calderón    43    Cra 99 12        NaN
# 14  1000098077          Laura     Torres    65      Av 5 34  3354422.0
#
#    Facebook Twitter
# 0        Si      Si
# 1        Si     NaN
# 2        No     NaN
# 3        No     NaN
# 4        No      Si
# 5        No     NaN
# 6        Si     NaN
# 7        Si     NaN
# 8        Si      Si
# 9        Si     NaN
# 10       Si     NaN
# 11       Si     NaN
# 12      NaN      Si
# 13       Si     NaN
# 14       No      Si

# %%
dataset2 = pd.read_excel('../DataSets/dataset.xlsx',index_col='Id')
dataset2.drop(['Unnamed: 0'], axis=1,inplace=True)
dataset2
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43          NaN  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87          NaN  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679            Dayana  Velásquez    21          NaN  4350011.0       Si
# 15435211          Shirley    Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel       Ossa    36          NaN  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea   Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter
# Id
# 7658908         Si
# 1234325678     NaN
# 43567832       NaN
# 32567854       NaN
# 29876009        Si
# 1000987566     NaN
# 1001456765     NaN
# 71234543       NaN
# 70987899        Si
# 8765679        NaN
# 15435211       NaN
# 1000900877     NaN
# 98000654        Si
# 56432555       NaN
# 1000098077      Si

# %%
pd.DataFrame(dataset2.loc[7658908 , :]).transpose()
# Out:
#         Nombre  Apellido Edad    Dirección   Teléfono Facebook Twitter
# 7658908   Juan  Martínez   23  Calle 45 67  1234567.0       Si      Si

# %%
dataset2.describe()
# Out:
#             Edad      Teléfono
# count  15.000000  1.100000e+01
# mean   46.333333  4.045338e+06
# std    22.173558  2.518164e+06
# min    21.000000  1.122334e+06
# 25%    31.000000  2.863822e+06
# 50%    39.000000  3.354422e+06
# 75%    60.500000  5.011612e+06
# max    87.000000  9.876543e+06

# %% [markdown]
# # **Limpieza de la base de datos (DataFrame)**

# %%
df_sinnan = dataset2.dropna()
df_sinnan
# Out:
#            Nombre  Apellido  Edad    Dirección   Teléfono Facebook Twitter
# Id
# 7658908      Juan  Martínez    23  Calle 45 67  1234567.0       Si      Si
# 1000098077  Laura    Torres    65      Av 5 34  3354422.0       No      Si

# %%
df_sinnan2 = dataset2.fillna(0)
df_sinnan2
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43            0  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87            0  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        0.0       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        0.0       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        0.0       Si
# 8765679            Dayana  Velásquez    21            0  4350011.0       Si
# 15435211          Shirley    Cuartas    34            0  3159800.0       Si
# 1000900877         Isabel       Ossa    36            0  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0        0
# 56432555           Andrea   Calderón    43    Cra 99 12        0.0       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter
# Id
# 7658908         Si
# 1234325678       0
# 43567832         0
# 32567854         0
# 29876009        Si
# 1000987566       0
# 1001456765       0
# 71234543         0
# 70987899        Si
# 8765679          0
# 15435211         0
# 1000900877       0
# 98000654        Si
# 56432555         0
# 1000098077      Si

# %%
df_sinnan3 = dataset2.fillna({'Dirección':'Desconocida' , 'Teléfono':0})
df_sinnan3
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43  Desconocida  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87  Desconocida  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        0.0       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        0.0       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        0.0       Si
# 8765679            Dayana  Velásquez    21  Desconocida  4350011.0       Si
# 15435211          Shirley    Cuartas    34  Desconocida  3159800.0       Si
# 1000900877         Isabel       Ossa    36  Desconocida  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea   Calderón    43    Cra 99 12        0.0       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter
# Id
# 7658908         Si
# 1234325678     NaN
# 43567832       NaN
# 32567854       NaN
# 29876009        Si
# 1000987566     NaN
# 1001456765     NaN
# 71234543       NaN
# 70987899        Si
# 8765679        NaN
# 15435211       NaN
# 1000900877     NaN
# 98000654        Si
# 56432555       NaN
# 1000098077      Si

# %% [markdown]
# # **Búsqueda de información en el DF**

# %%
dataset2
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43          NaN  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87          NaN  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679            Dayana  Velásquez    21          NaN  4350011.0       Si
# 15435211          Shirley    Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel       Ossa    36          NaN  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea   Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter
# Id
# 7658908         Si
# 1234325678     NaN
# 43567832       NaN
# 32567854       NaN
# 29876009        Si
# 1000987566     NaN
# 1001456765     NaN
# 71234543       NaN
# 70987899        Si
# 8765679        NaN
# 15435211       NaN
# 1000900877     NaN
# 98000654        Si
# 56432555       NaN
# 1000098077      Si

# %%
dataset2[dataset2['Edad'] > 30]
# Out:
#                    Nombre  Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 1234325678          Mario      Soto    43          NaN  1122334.0       Si
# 43567832            Marta  Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela    Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia   Aguirre    87          NaN  5673212.0       No
# 1000987566         Camilo   Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan      Toro    37    Crr 12 87        NaN       Si
# 15435211          Shirley   Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel      Ossa    36          NaN  9876543.0       Si
# 98000654     Maria Camila     Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea  Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura    Torres    65      Av 5 34  3354422.0       No
#
#            Twitter
# Id
# 1234325678     NaN
# 43567832       NaN
# 32567854       NaN
# 29876009        Si
# 1000987566     NaN
# 1001456765     NaN
# 15435211       NaN
# 1000900877     NaN
# 98000654        Si
# 56432555       NaN
# 1000098077      Si

# %%
dataset2[dataset2.Edad < 30]
# Out:
#                Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908          Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 71234543      Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899  Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679        Dayana  Velásquez    21          NaN  4350011.0       Si
#
#          Twitter
# Id
# 7658908       Si
# 71234543     NaN
# 70987899      Si
# 8765679      NaN

# %%
dataset2[(dataset2['Facebook'] =='Si') | ~(dataset2['Twitter'] == 'Si')]
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43          NaN  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679            Dayana  Velásquez    21          NaN  4350011.0       Si
# 15435211          Shirley    Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel       Ossa    36          NaN  9876543.0       Si
# 56432555           Andrea   Calderón    43    Cra 99 12        NaN       Si
#
#            Twitter
# Id
# 7658908         Si
# 1234325678     NaN
# 43567832       NaN
# 32567854       NaN
# 1000987566     NaN
# 1001456765     NaN
# 71234543       NaN
# 70987899        Si
# 8765679        NaN
# 15435211       NaN
# 1000900877     NaN
# 56432555       NaN

# %%
dataprub
# Out:
#                    Nombre  Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan  Martínez    23  Calle 45 67  1234567.0       Si
# 43567832            Marta  Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela    Zapata    76     Av 32 98  2567843.0       No
# 1000987566         Camilo   Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan      Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando  Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos    Suarez    23  Trans 56 21        NaN       Si
# 98000654     Maria Camila     Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea  Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura    Torres    65      Av 5 34  3354422.0       No
#
#            Twitter Año_nacimiento       Nombre completo
# Id
# 7658908         Si           2000         Juan Martínez
# 43567832       NaN           1967        Marta Cárdenas
# 32567854       NaN           1947  Diana Marcela Zapata
# 1000987566     NaN           1939        Camilo Aguilar
# 1001456765     NaN           1986         Jhonatan Toro
# 71234543       NaN           1995      Armando Pulgarín
# 70987899        Si           2000    Juan Carlos Suarez
# 98000654        Si           1984    Maria Camila Ortiz
# 56432555       NaN           1980       Andrea Calderón
# 1000098077      Si           1958          Laura Torres

# %%
dataprub=dataset2
dataprub.drop(dataprub[dataprub['Dirección'].isnull()].index)
# Out:
#                    Nombre  Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan  Martínez    23  Calle 45 67  1234567.0       Si
# 43567832            Marta  Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela    Zapata    76     Av 32 98  2567843.0       No
# 1000987566         Camilo   Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan      Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando  Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos    Suarez    23  Trans 56 21        NaN       Si
# 98000654     Maria Camila     Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea  Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura    Torres    65      Av 5 34  3354422.0       No
#
#            Twitter Año_nacimiento       Nombre completo
# Id
# 7658908         Si           2000         Juan Martínez
# 43567832       NaN           1967        Marta Cárdenas
# 32567854       NaN           1947  Diana Marcela Zapata
# 1000987566     NaN           1939        Camilo Aguilar
# 1001456765     NaN           1986         Jhonatan Toro
# 71234543       NaN           1995      Armando Pulgarín
# 70987899        Si           2000    Juan Carlos Suarez
# 98000654        Si           1984    Maria Camila Ortiz
# 56432555       NaN           1980       Andrea Calderón
# 1000098077      Si           1958          Laura Torres

# %%
dataset2[dataset2['Nombre'].str.contains('m')]
# Out:
#                   Nombre  Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 1000987566        Camilo   Aguilar    84    Cll 45 90        NaN       No
# 71234543         Armando  Pulgarín    28     Cir 5 67  3249988.0       Si
# 98000654    Maria Camila     Ortiz    39  Calle 66 11  6453211.0      NaN
#
#            Twitter
# Id
# 1000987566     NaN
# 71234543       NaN
# 98000654        Si

# %% [markdown]
# # **Transformación de datos**

# %%
from datetime import datetime 
from datetime import timedelta

def year(edad):
    now = datetime.now()
    y = now - timedelta(days=edad*365)
    return y.strftime('%Y')

dataset2['Año_nacimiento'] = dataset2['Edad'].apply(year)

dataset2
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43          NaN  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87          NaN  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679            Dayana  Velásquez    21          NaN  4350011.0       Si
# 15435211          Shirley    Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel       Ossa    36          NaN  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea   Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter Año_nacimiento
# Id
# 7658908         Si           2000
# 1234325678     NaN           1980
# 43567832       NaN           1967
# 32567854       NaN           1947
# 29876009        Si           1936
# 1000987566     NaN           1939
# 1001456765     NaN           1986
# 71234543       NaN           1995
# 70987899        Si           2000
# 8765679        NaN           2002
# 15435211       NaN           1989
# 1000900877     NaN           1987
# 98000654        Si           1984
# 56432555       NaN           1980
# 1000098077      Si           1958

# %%
def operacion(col):
    result = col['Nombre'] + ' ' + col['Apellido']
    return result

dataset2['Nombre completo'] = dataset2.apply(operacion, axis=1 )
dataset2
# Out:
#                    Nombre   Apellido  Edad    Dirección   Teléfono Facebook  \
# Id
# 7658908              Juan   Martínez    23  Calle 45 67  1234567.0       Si
# 1234325678          Mario       Soto    43          NaN  1122334.0       Si
# 43567832            Marta   Cárdenas    56    Cra 23 98  3456787.0       No
# 32567854    Diana Marcela     Zapata    76     Av 32 98  2567843.0       No
# 29876009    Maria Cecilia    Aguirre    87          NaN  5673212.0       No
# 1000987566         Camilo    Aguilar    84    Cll 45 90        NaN       No
# 1001456765       Jhonatan       Toro    37    Crr 12 87        NaN       Si
# 71234543          Armando   Pulgarín    28     Cir 5 67  3249988.0       Si
# 70987899      Juan Carlos     Suarez    23  Trans 56 21        NaN       Si
# 8765679            Dayana  Velásquez    21          NaN  4350011.0       Si
# 15435211          Shirley    Cuartas    34          NaN  3159800.0       Si
# 1000900877         Isabel       Ossa    36          NaN  9876543.0       Si
# 98000654     Maria Camila      Ortiz    39  Calle 66 11  6453211.0      NaN
# 56432555           Andrea   Calderón    43    Cra 99 12        NaN       Si
# 1000098077          Laura     Torres    65      Av 5 34  3354422.0       No
#
#            Twitter Año_nacimiento        Nombre completo
# Id
# 7658908         Si           2000          Juan Martínez
# 1234325678     NaN           1980             Mario Soto
# 43567832       NaN           1967         Marta Cárdenas
# 32567854       NaN           1947   Diana Marcela Zapata
# 29876009        Si           1936  Maria Cecilia Aguirre
# 1000987566     NaN           1939         Camilo Aguilar
# 1001456765     NaN           1986          Jhonatan Toro
# 71234543       NaN           1995       Armando Pulgarín
# 70987899        Si           2000     Juan Carlos Suarez
# 8765679        NaN           2002       Dayana Velásquez
# 15435211       NaN           1989        Shirley Cuartas
# 1000900877     NaN           1987            Isabel Ossa
# 98000654        Si           1984     Maria Camila Ortiz
# 56432555       NaN           1980        Andrea Calderón
# 1000098077      Si           1958           Laura Torres

# %% [markdown]
# # **Usar el groupby()**

# %%
df12 = dataset2.groupby('Facebook').count()
df12
# Out:
#           Nombre  Apellido  Edad  Dirección  Teléfono  Twitter  \
# Facebook
# No             5         5     5          4         4        2
# Si             9         9     9          5         6        2
#
#           Año_nacimiento  Nombre completo
# Facebook
# No                     5                5
# Si                     9                9

# %%
dataset2.describe()
# Out:
#             Edad      Teléfono
# count  15.000000  1.100000e+01
# mean   46.333333  4.045338e+06
# std    22.173558  2.518164e+06
# min    21.000000  1.122334e+06
# 25%    31.000000  2.863822e+06
# 50%    39.000000  3.354422e+06
# 75%    60.500000  5.011612e+06
# max    87.000000  9.876543e+06
